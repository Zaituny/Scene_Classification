# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
import tensorflow_hub as hub

# %%
train_dir = #path to train dataset
test_dir  = #path to test dataset

# %%
from matplotlib.image import imread

dim1 = []
dim2 = []

for image_file_name in os.listdir(train_dir + '/buildings/'):
    img = imread(train_dir + '/buildings/' + image_file_name)
    d1, d2, colors = img.shape
    dim1.append(d1)
    dim2.append(d2)

# %%
sns.jointplot(dim1, dim2)

# %%
np.mean(dim1)

# %%
np.max(dim1), np.max(dim2)

# %%
np.min(dim1), np.min(dim2)

# %%
plt.imshow(imread(train_dir + '\\buildings\\92.jpg'))
plt.colorbar()

# %%
plt.imshow(imread(train_dir + '\\forest\\8.jpg'))
plt.colorbar()

# %%
IMG_SIZE = (150, 150)

# %%
import shutil

def create_train_test_split(training_dir):
    
    train_path = training_dir + 'training_set'
    test_path = training_dir + 'test_set' 
    shutil.rmtree(train_path, ignore_errors = True)
    shutil.rmtree(test_path, ignore_errors = True)
    os.mkdir(train_path)
    os.mkdir(test_path)
    for subdir in os.listdir(training_dir):
        if subdir == 'training_set' or subdir == 'test_set':
            pass
        else:
            os.mkdir(train_path + '\\'+ subdir)
            os.mkdir(test_path + '\\'+ subdir)
    
    for subdir in os.listdir(training_dir):
        taken = []
        if subdir == 'training_set' or subdir == 'test_set':
            pass
        else:
            for i in range(int(0.7*len(os.listdir(training_dir + subdir)))):
                train_choice = np.random.randint(low = 0, high = len(os.listdir(training_dir + subdir)))
                while train_choice in taken:
                    train_choice = np.random.randint(low = 0, high = len(os.listdir(training_dir + subdir)))
                taken.append(train_choice)
                shutil.copy(training_dir + subdir + '\\' + os.listdir(training_dir + subdir)[train_choice], train_path + '\\' + subdir)
                
            for i in range(int(0.3*len(os.listdir(training_dir + subdir)))):
                test_choice = np.random.randint(low = 0, high = len(os.listdir(training_dir + subdir)))
                while test_choice in taken:
                    test_choice = np.random.randint(low = 0, high = len(os.listdir(training_dir + subdir)))
                taken.append(test_choice)
                shutil.copy(training_dir + subdir + '\\' + os.listdir(training_dir + subdir)[test_choice], test_path + '\\' + subdir)

# %%
create_train_test_split('C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\Scenes training set\\')

# %%
def create_balanced_data_set(class_name, src_dir, dist_dir, num_of_img_per_class):
    for my_class in os.listdir(src_dir):
        taken = []
        if my_class == class_name:
            pass
        else:
            for i in range(num_of_img_per_class):
                choice = np.random.randint(low = 0, high = len(os.listdir(src_dir + '/' + my_class)))
                while choice in taken:
                    choice = np.random.randint(low = 0, high = len(os.listdir(src_dir + '/' + my_class)))
                taken.append(choice)
                shutil.copy(src_dir + '/' + my_class + '/' + os.listdir(src_dir + '/' + my_class)[choice],
                           dist_dir)

# %%
create_balanced_data_set('street',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/training_set',
                        'C:/Users/Mohamed Ali/Downloads/street/train_set/not_street/',
                        300)

# %%
create_balanced_data_set('street',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/test_set',
                        'C:/Users/Mohamed Ali/Downloads/street/test_set/not_street/',
                        130)

# %%
create_balanced_data_set('sea',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/training_set',
                        'C:/Users/Mohamed Ali/Downloads/sea/train_set/not_sea/',
                        300)

# %%
create_balanced_data_set('sea',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/test_set',
                        'C:/Users/Mohamed Ali/Downloads/sea/test_set/not_sea/',
                        130)

# %%
create_balanced_data_set('glacier',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/training_set',
                        'C:/Users/Mohamed Ali/Downloads/glacier/train_set/not_glacier/',
                        300)

# %%
create_balanced_data_set('glacier',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/test_set',
                        'C:/Users/Mohamed Ali/Downloads/glacier/test_set/not_glacier/',
                        130)

# %%
create_balanced_data_set('mountain',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/training_set',
                        'C:/Users/Mohamed Ali/Downloads/mountain/train_set/not_mountain/',
                        300)

# %%
create_balanced_data_set('mountain',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/test_set',
                        'C:/Users/Mohamed Ali/Downloads/mountain/test_set/not_mountain/',
                        130)

# %%
create_balanced_data_set('forest',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/training_set',
                        'C:/Users/Mohamed Ali/Downloads/forest/train_set/not_forest/',
                        300)

# %%
create_balanced_data_set('forest',
                        'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/test_set',
                        'C:/Users/Mohamed Ali/Downloads/forest/test_set/not_forest/',
                        130)

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
# Out:
# Found 14487 files belonging to 6 classes.

# %%
train_data.class_names
# Out:
# ['buildings', 'forest', 'glacier', 'mountain', 'sea', 'street']

# %%
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='accuracy',
    min_delta=0,
    patience=5,
    verbose=1,
    mode='auto',
    baseline=None,
    restore_best_weights=True
)

# %%
model_name = ''
checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

# %%
model_name = 'model_0_fulldata'

base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_0_fulldata = tf.keras.Model(inputs, outputs)

model_0_fulldata.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_0 = model_0_fulldata.fit(train_data,
                     epochs=50,
                     callbacks=[early_stop, checkpoint_callback])
# Out:
# Epoch 1/50
# ...
# 453/453 [==============================] - 180s 386ms/step - loss: 0.3290 - accuracy: 0.8934
# Epoch 2/50
# ...
# 453/453 [==============================] - 170s 373ms/step - loss: 0.2119 - accuracy: 0.9248
# Epoch 3/50
# ...
# 453/453 [==============================] - 170s 373ms/step - loss: 0.1887 - accuracy: 0.9337
# Epoch 4/50
# ...
# 453/453 [==============================] - 167s 365ms/step - loss: 0.1773 - accuracy: 0.9378
# Epoch 5/50
# ...
# 453/453 [==============================] - 166s 365ms/step - loss: 0.1646 - accuracy: 0.9415
# Epoch 6/50
# ...
# 453/453 [==============================] - 171s 374ms/step - loss: 0.1567 - accuracy: 0.9452
# Epoch 7/50
# ...
# 453/453 [==============================] - 168s 368ms/step - loss: 0.1515 - accuracy: 0.9467
# Epoch 8/50
# ...
# 453/453 [==============================] - 169s 370ms/step - loss: 0.1456 - accuracy: 0.9483
# Epoch 9/50
# ...
# 453/453 [==============================] - 169s 371ms/step - loss: 0.1407 - accuracy: 0.9502
# Epoch 10/50
# ...

# %%
base_model.layers[-1].trainable = True
model_0_fulldata.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              metrics=["accuracy"])
history_1 = model_0_fulldata.fit(train_data,
                     epochs=50,
                     callbacks=[early_stop, checkpoint_callback])
# Out:
# Epoch 1/50
# ...
# 453/453 [==============================] - 171s 368ms/step - loss: 0.0894 - accuracy: 0.9675
# Epoch 2/50
# ...
# 453/453 [==============================] - 153s 335ms/step - loss: 0.0884 - accuracy: 0.9691
# Epoch 3/50
# ...
# 453/453 [==============================] - 153s 334ms/step - loss: 0.0880 - accuracy: 0.9687
# Epoch 4/50
# ...
# 453/453 [==============================] - 152s 334ms/step - loss: 0.0869 - accuracy: 0.9681
# Epoch 5/50
# ...
# 453/453 [==============================] - 153s 335ms/step - loss: 0.0884 - accuracy: 0.9691
# Epoch 6/50
# ...
# 453/453 [==============================] - 150s 329ms/step - loss: 0.0880 - accuracy: 0.9680
# Epoch 7/50
# ...
# 453/453 [==============================] - 161s 354ms/step - loss: 0.0863 - accuracy: 0.9696
# Epoch 8/50
# ...
# 453/453 [==============================] - 152s 333ms/step - loss: 0.0883 - accuracy: 0.9691
# Epoch 9/50
# ...
# 453/453 [==============================] - 153s 335ms/step - loss: 0.0890 - accuracy: 0.9685
# Epoch 10/50
# ...

# %%
from matplotlib.image import imread
my_predictions = []
for img in os.listdir(test_dir):
    my_predictions.append(np.argmax(model_0_fulldata.predict(np.expand_dims(imread(test_dir+ '/' + img), axis = 0))))
    
my_predictions_np_array = np.array(my_predictions)
# Out:
# ...
# 1/1 [==============================] - 0s 37ms/step
# ...
# ...
# 1/1 [==============================] - 0s 60ms/step

# %%
my_dict = {'Image': os.listdir(test_dir), 'Label': my_predictions_np_array}
df = pd.DataFrame(my_dict)

df.to_csv('full_data.csv')

# %%
model_0.evaluate(test_data)

# %%
model_0.save('exp1_model_0')

# %%
from tensorflow.keras.layers.experimental import preprocessing
data_augmentation = tf.keras.Sequential([
  preprocessing.RandomFlip("horizontal"),
  preprocessing.RandomRotation(0.2),
  preprocessing.RandomZoom(0.2),
  preprocessing.RandomHeight(0.2),
  preprocessing.RandomWidth(0.2),],
  name ="data_augmentation")

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import random
target_class = random.choice(train_data.class_names) # choose a random class
target_dir = "C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes training set/training_set/" + target_class # create the target directory
random_image = random.choice(os.listdir(target_dir)) # choose a random image from target directory
random_image_path = target_dir + "/" + random_image # create the choosen random image path
img = mpimg.imread(random_image_path) # read in the chosen target image
plt.imshow(img) # plot the target image
plt.title(f"Original random image from class: {target_class}")
plt.axis(False); # turn off the axes

# Augment the image
augmented_img = data_augmentation(tf.expand_dims(img, axis=0), training = True) # data augmentation model requires shape (None, height, width, 3)
plt.figure()
plt.imshow(tf.squeeze(augmented_img)/255.) # requires normalization after augmentation
plt.title(f"Augmented random image from class: {target_class}")
plt.axis(False);

# %%
model_name = 'model_1'

base_model = tf.keras.applications.EfficientNetB0(include_top=False)
base_model.trainable = False

input_shape = (150, 150, 3)

inputs = tf.keras.layers.Input(shape=input_shape, name="input_layer")

x = data_augmentation(inputs)

x = base_model(x, training=False)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_1 = tf.keras.Model(inputs, outputs)

model_1.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_1 = model_1.fit(train_data,
                       epochs = 10,
                       validation_data = test_data,
                       callbacks = [early_stop, checkpoint_callback])

# %%
model_1.save('exp_2_model_1')

# %%
data_augmentation = tf.keras.Sequential([
  preprocessing.RandomFlip("horizontal"),
  preprocessing.RandomFlip("vertical"),
  preprocessing.RandomZoom(0.2),
  preprocessing.RandomHeight(0.2),
  preprocessing.RandomWidth(0.2),],
  name ="data_augmentation")

# %%
history_2 = model_1.fit(train_data,
                       epochs = 10,
                       validation_data = test_data,
                       callbacks = [early_stop, checkpoint_callback])

# %%
data_augmentation_1 = tf.keras.Sequential([
  preprocessing.RandomFlip("horizontal"),
  preprocessing.RandomFlip("vertical"),
  preprocessing.RandomZoom(0.2),
  preprocessing.RandomHeight(0.2),
  preprocessing.RandomWidth(0.2),
  preprocessing.Rescaling(1./255)],
  name ="data_augmentation_1")

# %%
model_name = 'model_2'

base_model_1 = tf.keras.applications.ResNet50V2(include_top=False)
base_model_1.trainable = False

input_shape = (150, 150, 3)

inputs = tf.keras.layers.Input(shape=input_shape, name="input_layer")

x = data_augmentation(inputs)

x = base_model_1(x, training=False)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_2 = tf.keras.Model(inputs, outputs)

model_2.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_3 = model_2.fit(train_data,
                       epochs = 10,
                       validation_data = test_data,
                       callbacks = [early_stop, checkpoint_callback])

# %%
model_name = 'model_3'
base_model_2 = tf.keras.applications.EfficientNetB4(include_top=False)

base_model_2.trainable = False

input_shape = (150, 150, 3)

inputs = tf.keras.layers.Input(shape=input_shape, name="input_layer")

x = data_augmentation(inputs)

x = base_model_1(x, training=False)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_3 = tf.keras.Model(inputs, outputs)

model_3.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_4 = model_3.fit(train_data,
                       epochs = 50,
                       validation_data = test_data,
                       callbacks = [early_stop, checkpoint_callback])

# %%
model_name = 'model_4'

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_2(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_3 = tf.keras.Model(inputs, outputs)

model_3.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_5 = model_3.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
base_model_3 = tf.keras.applications.MobileNet(include_top=False)
base_model_3.trainable = False

# %%
base_model_3.layers

# %%
model_name = 'model_4'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

input_shape = (150, 150, 3)

inputs = tf.keras.layers.Input(shape=input_shape, name="input_layer")

x = data_augmentation(inputs)

x = base_model_3(x, training=False)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_4 = tf.keras.Model(inputs, outputs)

model_4.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_5 = model_4.fit(train_data,
                       epochs = 50,
                       validation_data = test_data,
                       callbacks = [early_stop, checkpoint_callback])

# %%
model_0 = tf.keras.models.load_model('exp1_model_0')

# %%
model_name = 'model_5'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model = tf.keras.applications.EfficientNetB0(include_top=False)
base_model.trainable = False
base_model.layers[-1].trainable = True

model_0.compile(loss="categorical_crossentropy",
              optimizer=tf.keras.optimizers.Adam(lr=0.0001), # lr is 10x lower than before for fine-tuning
              metrics=["accuracy"])
history_6 = model_0.fit(train_data,
                       epochs = 5,
                       validation_data = test_data,
                       callbacks=[early_stop, checkpoint_callback])

# %%
tf.keras.models.save_model(model=model_0, filepath='model_0_with_cleaned_data')

# %%
history_7 = model_0.fit(train_data,
                       epochs = 10,
                       validation_data = test_data,
                       initial_epoch=history_6.epoch[-1],
                       callbacks=[early_stop, checkpoint_callback])

# %%
my_predictions = []
img_names = []
for img in os.listdir(test_dir):
    my_predictions.append(np.argmax(model_0.predict(np.expand_dims(imread(test_dir+ '/' + img), axis = 0))))
    img_names.append(img)
    
my_predictions_np_array = np.array(my_predictions)
my_img_names_np_array = np.array(img_names)

# %%
my_dict = {'Image': my_img_names_np_array, 'Label': my_predictions_np_array}
df = pd.DataFrame(my_dict)

# %%
df.to_csv('submit.csv')

# %%
my_predictions

# %%
buildingVsStreet_train_dir = 'C:/Users/Mohamed Ali/Downloads/buildingVs.street/Train_set'
buildingVsStreet_test_dir = 'C:/Users/Mohamed Ali/Downloads/buildingVs.street/Test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = buildingVsStreet_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = buildingVsStreet_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_5'
checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_5 = tf.keras.Model(inputs, outputs)

model_5.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# history_8 = model_5.fit(train_data,
#                      epochs=50,
#                      validation_data = test_data,
#                      callbacks=[early_stop, checkpoint_callback])

# %%
model_name = 'model_5_fine_tuned'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model.layers[-1].trainable = True
model_5.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
              metrics=["accuracy"])

# history_9 = model_5.fit(train_data,
#                      epochs=50,
#                      initial_epoch=history_8.epoch[12],
#                      validation_data = test_data,
#                      callbacks=[early_stop, checkpoint_callback])

# %%
building_train_dir = 'C:/Users/Mohamed Ali/Downloads/building/train_set'
building_test_dir = 'C:/Users/Mohamed Ali/Downloads/building/test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = building_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = building_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_6'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_6 = tf.keras.Model(inputs, outputs)

model_6.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_10 = model_6.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
street_train_dir = 'C:/Users/Mohamed Ali/Downloads/street/train_set'
street_test_dir = 'C:/Users/Mohamed Ali/Downloads/street/test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = street_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = street_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_7'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_7 = tf.keras.Model(inputs, outputs)

model_7.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_11 = model_7.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
sea_train_dir = 'C:/Users/Mohamed Ali/Downloads/sea/train_set'
sea_test_dir = 'C:/Users/Mohamed Ali/Downloads/sea/test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = sea_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = sea_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
train_data.class_names

# %%
model_name = 'model_8'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_8 = tf.keras.Model(inputs, outputs)

model_8.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_12 = model_8.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
mountain_train_dir = 'C:/Users/Mohamed Ali/Downloads/mountain/train_set'
mountain_test_dir = 'C:/Users/Mohamed Ali/Downloads/mountain/test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = mountain_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = mountain_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_9'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_9 = tf.keras.Model(inputs, outputs)

model_9.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_13 = model_9.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
forest_train_dir = 'C:/Users/Mohamed Ali/Downloads/forest/train_set'
forest_test_dir = 'C:/Users/Mohamed Ali/Downloads/forest/test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = forest_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = forest_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_10'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_10 = tf.keras.Model(inputs, outputs)

model_10.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_14 = model_10.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
glacier_train_dir = 'C:/Users/Mohamed Ali/Downloads/glacier/train_set'
glacier_test_dir = 'C:/Users/Mohamed Ali/Downloads/glacier/test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = glacier_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = glacier_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_11'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)
base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_11 = tf.keras.Model(inputs, outputs)

model_11.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_15 = model_11.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop, checkpoint_callback])

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = mountain_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = mountain_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
base_model.layers[-1].trainable = True

# %%
model_name = 'model_12'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

history_16 = model_9.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     initial_epoch=history_13.epoch[13],
                     callbacks=[early_stop, checkpoint_callback])

# %%
for layer in base_model.layers[-10:]:
    layer.trainable = True

# %%
model_name = 'model_13'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

history_17 = model_9.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     initial_epoch=history_13.epoch[13],
                     callbacks=[early_stop, checkpoint_callback])

# %%
model_0.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/model_5_checkpoints'))
model_0.evaluate(test_data)

# %%
my_predictions = []
for img in os.listdir(test_dir):
    if np.argmax(model_10.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 0:
        my_predictions.append(1)
    else:
        if np.argmax(model_8.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 1:
            my_predictions.append(4)
        else:
            if np.argmax(model_6.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 0:
                my_predictions.append(0)
            else:
                if np.argmax(model_7.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 1:
                    my_predictions.append(5)
                else:
                    if np.argmax(model_11.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 0:
                        my_predictions.append(2)
                    else:
                        if np.argmax(model_9.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 0:
                            my_predictions.append(3)
                        else:
                            my_predictions.append(np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))))

my_predictions_np_array = np.array(my_predictions)

# %%
my_dict = {'Image': np.array(os.listdir(test_dir)), 'Label': my_predictions_np_array}
df = pd.DataFrame(my_dict)

df.to_csv('submit.csv')

# %%
my_img_names_np_array.shape

# %%
my_predictions_np_array.shape

# %%
df = pd.read_csv('submit.csv')
df2 = pd.read_csv('C:/Users/Mohamed Ali/Documents/submit.csv')

# %%
df.compare(df2,align_axis=0)

# %%
from tensorflow.keras.layers.experimental import preprocessing
data_augmentation = tf.keras.Sequential([preprocessing.Rescaling(1./255)],
  name ="data_augmentation")

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir + '\\training_set',
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir + '\\test_set',
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_13'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.ResNet50V2(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_13 = tf.keras.Model(inputs, outputs)

model_13.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_18 = model_13.fit(train_data,
                     epochs=10,
                     validation_data = test_data,
                     callbacks=[checkpoint_callback])

# %%
model_name = 'model_14'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.ConvNeXtSmall(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_13 = tf.keras.Model(inputs, outputs)

model_13.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_18 = model_13.fit(train_data,
                     epochs=10,
                     validation_data = test_data,
                     callbacks=[checkpoint_callback])

# %%
for layer in base_model_1.layers[-10:]:
    layer.trainable = True

# %%
def plot_loss_curves(history):
  """
  Returns separate loss curves for training and validation metrics.
  """ 
  loss = history.history['loss']
  val_loss = history.history['val_loss']

  accuracy = history.history['accuracy']
  val_accuracy = history.history['val_accuracy']

  epochs = range(len(history.history['loss']))

  # Plot loss
  plt.plot(epochs, loss, label='training_loss')
  plt.plot(epochs, val_loss, label='val_loss')
  plt.title('Loss')
  plt.xlabel('Epochs')
  plt.legend()

  # Plot accuracy
  plt.figure()
  plt.plot(epochs, accuracy, label='training_accuracy')
  plt.plot(epochs, val_accuracy, label='val_accuracy')
  plt.title('Accuracy')
  plt.xlabel('Epochs')
  plt.legend();

# %%
plot_loss_curves(history_18)

# %%
plot_loss_curves(history_10)

# %%
plot_loss_curves(history_11)

# %%
plot_loss_curves(history_12)

# %%
plot_loss_curves(history_13)

# %%
plot_loss_curves(history_14)

# %%
plot_loss_curves(history_15)

# %%
plot_loss_curves(history_6)

# %%
model_13.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate = 0.0001),
              metrics=["accuracy"])

history_19 = model_13.fit(train_data,
                     epochs=15,
                     validation_data = test_data,
                     initial_epoch=history_18.epoch[-1],
                     callbacks=[checkpoint_callback])

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
predictions = model_13.predict(test_data)

# %%
predictions

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir + '\\training_set',
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 1)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir + '\\test_set',
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 1)

# %%
def confusion_matrix_prepair(model, testData):
    predict = np.array([])
    labels =  np.array([])
    for x, y in testData:
      predict = np.concatenate([predict, np.argmax(model.predict(x), axis = 1)])
      labels = np.concatenate([labels, np.argmax(y.numpy(), axis=-1)])
    return predict, labels

# %%
predict, labels = confusion_matrix_prepair(model_13, test_data)

# %%
cm = confusion_matrix(labels, predict, labels=[0,1,2,3,4,5])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=[0,1,2,3,4,5])
disp.plot()

# %%
predict, labels = confusion_matrix_prepair(model_0, test_data)

# %%
cm = confusion_matrix(labels, predict, labels=[0,1,2,3,4,5])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=[0,1,2,3,4,5])
disp.plot()

# %%
buildingVsStreet_train_dir = 'C:/Users/Mohamed Ali/Downloads/buildingVs.street/Train_set'
buildingVsStreet_test_dir = 'C:/Users/Mohamed Ali/Downloads/buildingVs.street/Test_set'

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = buildingVsStreet_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = buildingVsStreet_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_15'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.ConvNeXtTiny(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_14 = tf.keras.Model(inputs, outputs)

model_14.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_18 = model_14.fit(train_data,
                     epochs=10,
                     validation_data = test_data,
                     callbacks=[checkpoint_callback])

# %%
model_name = 'model_16'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.EfficientNetV2B0(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_15 = tf.keras.Model(inputs, outputs)

model_15.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_18 = model_15.fit(train_data,
                     epochs=10,
                     validation_data = test_data,
                     callbacks=[checkpoint_callback])

# %%
train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir + '\\training_set',
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = train_dir + '\\test_set',
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'model_17'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.EfficientNetV2B0(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_16 = tf.keras.Model(inputs, outputs)

model_16.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# history_19 = model_16.fit(train_data,
#                      epochs=10,
#                      validation_data = test_data,
#                      callbacks=[checkpoint_callback])

# %%
for layer in base_model_1.layers[-10:]:
    layer.trainable = True

# %%
model_name = 'model_18'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

model_16.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(0.0001),
              metrics=["accuracy"])

# history_20 = model_16.fit(train_data,
#                      epochs=100,
#                      validation_data = test_data,
#                      initial_epoch= history_19.epoch[4],
#                      callbacks=[checkpoint_callback])

# %%
model_16.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/model_18_checkpoints'))

# %%
model_16.evaluate(test_data)

# %%
predict, labels = confusion_matrix_prepair(model_16, test_data)

# %%
cm = confusion_matrix(labels, predict, labels=[0,1,2,3,4,5])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=[0,1,2,3,4,5])
disp.plot()

# %%
buildingVsStreet_train_dir = 'C:/Users/Mohamed Ali/Downloads/buildingVs.street/Train_set'
buildingVsStreet_test_dir = 'C:/Users/Mohamed Ali/Downloads/buildingVs.street/Test_set'

# %%
buildingVsStreet_train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = buildingVsStreet_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)
buildingVsStreet_test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = buildingVsStreet_test_dir,
                                                               image_size = IMG_SIZE,
                                                               label_mode="categorical",
                                                               batch_size = 32)

# %%
model_name = 'buildingVs.Street'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.EfficientNetB0(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_buildingVsStreet = tf.keras.Model(inputs, outputs)

model_buildingVsStreet.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# history_19 = model_buildingVsStreet.fit(buildingVsStreet_train_data,
#                      epochs=50,
#                      validation_data = buildingVsStreet_test_data,
#                      callbacks=[early_stop,checkpoint_callback])

# %%
predict, labels = confusion_matrix_prepair(model_buildingVsStreet, buildingVsStreet_test_data)

# %%
cm = confusion_matrix(labels, predict, labels=[0,1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                               display_labels=[0,1])
disp.plot()

# %%
for layer in base_model_1.layers[-10:]:
    layer.trainable = False

# %%
model_name = 'buildingVs.Street_fine_tune'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

model_buildingVsStreet.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# history_20 = model_buildingVsStreet.fit(buildingVsStreet_train_data,
#                      epochs=50,
#                      validation_data = buildingVsStreet_test_data,
#                      callbacks=[checkpoint_callback])

# %%
model_buildingVsStreet.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/buildingVs.Street_fine_tune_checkpoints'))

# %%
model_buildingVsStreet.evaluate(buildingVsStreet_test_data)

# %%
predictions = np.argmax(model_buildingVsStreet.predict(buildingVsStreet_test_data), axis = 1)
labels =

# %%
for x, y in buildingVsStreet_test_data:
      predict = np.concatenate([predict, np.argmax(model_buildingVsStreet.predict(x), axis = 1)])
      labels = np.concatenate([labels, np.argmax(y.numpy(), axis=-1)])

# %%
glaciervsmountain_train_dir = 'C:/Users/Mohamed Ali/Downloads/glacierVsmountain/train_set'
glaciervsmountain_test_dir = 'C:/Users/Mohamed Ali/Downloads/glacierVsmountain/test_set'

# %%
glaciervsmountain_train_data = tf.keras.preprocessing.image_dataset_from_directory(directory = glaciervsmountain_train_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32) 
glaciervsmountain_test_data = tf.keras.preprocessing.image_dataset_from_directory(directory = glaciervsmountain_test_dir,
                                                                image_size = IMG_SIZE,
                                                                label_mode="categorical",
                                                                batch_size = 32)

# %%
model_name = 'glaciervsmountain'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.EfficientNetB0(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_glaciervsmountain = tf.keras.Model(inputs, outputs)

model_glaciervsmountain.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

# history_21 = model_glaciervsmountain.fit(buildingVsStreet_train_data,
#                      epochs=50,
#                      validation_data = buildingVsStreet_test_data,
#                      callbacks=[early_stop,checkpoint_callback])

# %%
model_buildingVsStreet.predict(np.expand_dims(imread('C:\\Users\\Mohamed Ali\\Downloads\\buildingVs.street\\test_set\\street\\8530.jpg'),axis = 0))

# %%
for img in os.listdir('C:\\Users\\Mohamed Ali\\Downloads\\buildingVs.street\\test_set\\street'):
    print(model_buildingVsStreet.predict(np.expand_dims(imread('C:\\Users\\Mohamed Ali\\Downloads\\buildingVs.street\\test_set\\street\\' + img),axis = 0)), img)

# %%
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf

from matplotlib.image import imread

test_dir  = 'C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/Scenes testing test'

base_model = tf.keras.applications.EfficientNetB0(include_top=False)

base_model.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_0 = tf.keras.Model(inputs, outputs)

model_0.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

base_model_1 = tf.keras.applications.EfficientNetB0(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_buildingVsStreet = tf.keras.Model(inputs, outputs)

model_buildingVsStreet.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])


base_model_2 = tf.keras.applications.EfficientNetB0(include_top=False)

base_model_2.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_2(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(2, activation="softmax", name="output_layer")(x)

model_glaciervsmountain = tf.keras.Model(inputs, outputs)

model_glaciervsmountain.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

base_model_3 = tf.keras.applications.EfficientNetV2B0(include_top=False)

base_model_3.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = base_model_3(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

model_16 = tf.keras.Model(inputs, outputs)

model_16.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])


model_0.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/model_5_checkpoints'))
model_buildingVsStreet.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/buildingVs.Street_checkpoints'))
model_glaciervsmountain.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/glaciervsmountain_checkpoints'))
model_16.load_weights(tf.train.latest_checkpoint('C:/Users/Mohamed Ali/Downloads/sprints-ai-and-ml-competition-2022-round-2/model_17_checkpoints'))
my_predictions = []
counter = 0
for img in os.listdir(test_dir):
#     if np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 0:
#         if model_buildingVsStreet.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))[0][0] >= 0.7:
#             my_predictions.append(0)
#         else:
#             my_predictions.append(5)
#     elif np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 5:
#         if model_buildingVsStreet.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))[0][1] >= 0.7:
#             my_predictions.append(5)
#         else:
#             my_predictions.append(0)
#     elif np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 2:
#         if model_glaciervsmountain.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))[0][0] >= 0.7:
#             my_predictions.append(2)
#         else:
#             my_predictions.append(3)
#     elif np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))) == 3:
#         if model_glaciervsmountain.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))[0][1] >= 0.7:
#             my_predictions.append(3)
#         else:
#             my_predictions.append(2)
#     else:
#         my_predictions.append(np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))))
    my_predictions.append(np.argmax(model_16.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0))))
    print(counter)
    counter += 1
my_predictions_np_array = np.array(my_predictions)
# Out:
# 1/1 [==============================] - 1s 888ms/step
# 0
# 1/1 [==============================] - 0s 28ms/step
# 1
# 1/1 [==============================] - 0s 29ms/step
# 2
# 1/1 [==============================] - 0s 27ms/step
# 3
# 1/1 [==============================] - 0s 30ms/step
# 4
# 1/1 [==============================] - 0s 31ms/step
# 5
# 1/1 [==============================] - 0s 64ms/step
# 6
# 1/1 [==============================] - 0s 29ms/step
# 7
# 1/1 [==============================] - 0s 29ms/step
# 8
# 1/1 [==============================] - 0s 31ms/step
# 9
# 1/1 [==============================] - 0s 29ms/step
# 10
# 1/1 [==============================] - 0s 32ms/step
# 11
# 1/1 [==============================] - 0s 34ms/step
# 12
# 1/1 [==============================] - 0s 31ms/step
# 13
# 1/1 [==============================] - 0s 29ms/step
# 14
# 1/1 [==============================] - 0s 28ms/step
# 15
# 1/1 [==============================] - 0s 33ms/step
# 16
# ...

# %%
my_dict = {'Image': np.array(os.listdir(test_dir)), 'Label': my_predictions_np_array}
df = pd.DataFrame(my_dict)

df.to_csv('submit.csv')

# %%
len(my_predictions_np_array)

# %%
test_dir

# %%
len(os.listdir(test_dir))

# %%
np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + '5.jpg'), axis = 0)), axis = 1) == 0

# %%
model_glaciervsmountain.predict(np.expand_dims(imread(test_dir + '/' +  '5.jpg'), axis = 0))[0][0] >= 0.7

# %%
model_glaciervsmountain.predict(np.expand_dims(imread(test_dir + '/' +  '5.jpg'), axis = 0))[0][0]

# %%
model_glaciervsmountain.predict(np.expand_dims(imread(test_dir + '/' +  '5.jpg'), axis = 0))

# %%
from tensorflow.keras.layers.experimental import preprocessing
data_augmentation = tf.keras.Sequential([
  preprocessing.RandomFlip("horizontal"),
  preprocessing.RandomRotation(0.2),
  preprocessing.RandomZoom(0.2),
  preprocessing.RandomHeight(0.2),
  preprocessing.RandomWidth(0.2),
  preprocessing.Rescaling(1./255)],
  name ="data_augmentation")

# %%
model_name = 'ResnetTest'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.RegNetX016(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = data_augmentation(inputs)

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

ResnetTest = tf.keras.Model(inputs, outputs)

ResnetTest.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_22 = ResnetTest.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop,checkpoint_callback])
# Out:
# Epoch 1/50
# 322/322 [==============================] - ETA: 0s - loss: 0.4156 - accuracy: 0.8645
# Epoch 1: val_loss improved from inf to 0.25223, saving model to C:\Users\Mohamed Ali\Downloads\sprints-ai-and-ml-competition-2022-round-2\ResnetTest_checkpoints\checkpt.ckpt
# 322/322 [==============================] - 245s 748ms/step - loss: 0.4156 - accuracy: 0.8645 - val_loss: 0.2522 - val_accuracy: 0.9116
# Epoch 2/50
# 322/322 [==============================] - ETA: 0s - loss: 0.2308 - accuracy: 0.9171
# Epoch 2: val_loss improved from 0.25223 to 0.22881, saving model to C:\Users\Mohamed Ali\Downloads\sprints-ai-and-ml-competition-2022-round-2\ResnetTest_checkpoints\checkpt.ckpt
# 322/322 [==============================] - 259s 799ms/step - loss: 0.2308 - accuracy: 0.9171 - val_loss: 0.2288 - val_accuracy: 0.9184
# Epoch 3/50
# 322/322 [==============================] - ETA: 0s - loss: 0.2050 - accuracy: 0.9279
# Epoch 3: val_loss did not improve from 0.22881
# ...

# %%
model_name = 'VGGTest'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.VGG16(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = data_augmentation(inputs)

x = base_model_1(inputs)

x = tf.keras.layers.GlobalAveragePooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

VGGTest = tf.keras.Model(inputs, outputs)

VGGTest.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_22 = VGGTest.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop,checkpoint_callback])
# Out:
# ...
# 58889256/58889256 [==============================] - 33s 1us/step
# Epoch 1/50
# 322/322 [==============================] - ETA: 0s - loss: 1.7712 - accuracy: 0.7211
# Epoch 1: val_loss improved from inf to 0.85108, saving model to C:\Users\Mohamed Ali\Downloads\sprints-ai-and-ml-competition-2022-round-2\VGGTest_checkpoints\checkpt.ckpt
# 322/322 [==============================] - 493s 2s/step - loss: 1.7712 - accuracy: 0.7211 - val_loss: 0.8511 - val_accuracy: 0.8340
# Epoch 2/50
# 322/322 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.8592
# Epoch 2: val_loss improved from 0.85108 to 0.66979, saving model to C:\Users\Mohamed Ali\Downloads\sprints-ai-and-ml-competition-2022-round-2\VGGTest_checkpoints\checkpt.ckpt
# 322/322 [==============================] - 486s 2s/step - loss: 0.6158 - accuracy: 0.8592 - val_loss: 0.6698 - val_accuracy: 0.8507
# Epoch 3/50
# 322/322 [==============================] - ETA: 0s - loss: 0.4504 - accuracy: 0.8815
# ...

# %%
model_name = 'ResnetTest1'

checkpoint_path = f'C:\\Users\\Mohamed Ali\\Downloads\\sprints-ai-and-ml-competition-2022-round-2\\{model_name}_checkpoints\\checkpt.ckpt'
checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                         save_weights_only=True, # set to False to save the entire model
                                                         save_best_only=True, # set to True to save only the best model instead of a model every epoch 
                                                         save_freq="epoch", # save every epoch
                                                         verbose=1)

base_model_1 = tf.keras.applications.RegNetX016(include_top=False)

base_model_1.trainable = False

inputs = tf.keras.layers.Input(shape=(150, 150, 3), name="input_layer")

x = data_augmentation(inputs)

x = base_model_1(inputs)

x = tf.keras.layers.GlobalMaxPooling2D(name="global_average_pooling_layer")(x)

outputs = tf.keras.layers.Dense(6, activation="softmax", name="output_layer")(x)

ResnetTest1 = tf.keras.Model(inputs, outputs)

ResnetTest1.compile(loss='categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(),
              metrics=["accuracy"])

history_22 = ResnetTest1.fit(train_data,
                     epochs=50,
                     validation_data = test_data,
                     callbacks=[early_stop,checkpoint_callback])
# Out:
# Epoch 1/50
# 322/322 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.8143
# Epoch 1: val_loss improved from inf to 0.31031, saving model to C:\Users\Mohamed Ali\Downloads\sprints-ai-and-ml-competition-2022-round-2\ResnetTest1_checkpoints\checkpt.ckpt
# 322/322 [==============================] - 243s 744ms/step - loss: 0.5224 - accuracy: 0.8143 - val_loss: 0.3103 - val_accuracy: 0.8859
# Epoch 2/50
# 322/322 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.9016
# Epoch 2: val_loss improved from 0.31031 to 0.28479, saving model to C:\Users\Mohamed Ali\Downloads\sprints-ai-and-ml-competition-2022-round-2\ResnetTest1_checkpoints\checkpt.ckpt
# 322/322 [==============================] - 234s 720ms/step - loss: 0.2732 - accuracy: 0.9016 - val_loss: 0.2848 - val_accuracy: 0.8980
# Epoch 3/50
# 322/322 [==============================] - ETA: 0s - loss: 0.2305 - accuracy: 0.9176
# ...

# %%
my_predictions = []
for img in os.listdir(test_dir):
    pred_array = [0,0,0,0,0,0]
    pred_array[np.argmax(model_0.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0)))]     += 1
    pred_array[np.argmax(model_16.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0)))]    += 1
    pred_array[np.argmax(ResnetTest.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0)))]  += 1
    pred_array[np.argmax(ResnetTest1.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0)))] += 1
    pred_array[np.argmax(VGGTest.predict(np.expand_dims(imread(test_dir + '/' + img), axis = 0)))]     += 1
    my_predictions.append(np.argmax(pred_array))
my_predictions_array = np.array(my_predictions)
# Out:
# ...
# 1/1 [==============================] - 1s 662ms/step
# WARNING:tensorflow:5 out of the last 2196 calls to <function Model.make_predict_function.<locals>.predict_function at 0x000001AAC322A290> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ...
# 1/1 [==============================] - 0s 76ms/step
# ...
# ...
# 1/1 [==============================] - 1s 760ms/step

# %%
my_dict = {'Image': np.array(os.listdir(test_dir)), 'Label': my_predictions_np_array}
df = pd.DataFrame(my_dict)

df.to_csv('submit.csv')
